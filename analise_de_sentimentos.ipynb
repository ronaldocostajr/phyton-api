# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldocostajr/phyton-api/blob/master/analise_de_sentimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Carregando os dados

# %%
import pandas as pd

df = pd.read_csv('delivery_alimentos.csv')
df.head()
# Out:
#    Unnamed: 0                              reviewId                userName  \
# 0           0  2cf8d528-4be9-4582-8029-b12c7853ba9c         Daniela Aguilar
# 1           1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50  Arlan Cruz (Miguelito)
# 2           2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1         Gabriel Liondas
# 3           3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15            Ester Araújo
# 4           4  9c203cc4-289f-46cf-b55a-6332791b3b8c                 Adr_Alv
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Fiz um pedido e veio com um item faltando. Ao ...      1            252
# ...

# %% [markdown]
# Analise dos dados

# %%
df.isnull().sum() # verifica a quantidade de nulos em todas as linhas
# Out:
# Unnamed: 0                  0
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     3361
# at                          0
# replyContent            27020
# repliedAt               27020
# appVersion               3361
# sortOrder                   0
# appId                       0
# dtype: int64

# %%
def check_nulls():
  number_null = df.isnull().sum()
  print(number_null, '\n')

# %%
check_nulls()
# Out:
# Unnamed: 0                  0
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     3361
# at                          0
# replyContent            27020
# repliedAt               27020
# appVersion               3361
# sortOrder                   0
# appId                       0
# dtype: int64

# %% [markdown]
# Contando palavas

# %%
df['word_count'] = df['content'].str.split().apply(len)
df['word_count']
# Out:
# 0        81
# 1        77
# 2        71
# 3        55
# 4        95
#          ..
# 35977     5
# 35978     2
# 35979     5
# 35980     2
# 35981    28
# Name: word_count, Length: 35982, dtype: int64

# %%
df['word_count'].min()
# Out:
# 1

# %%
df['word_count'].mean()
# Out:
# 28.090712022678005

# %%
df['word_count'].max()
# Out:
# 350

# %%
df[df['word_count'] == 1]
# Out:
#        Unnamed: 0                              reviewId  \
# 344           344  88654cfe-d9ba-40cf-ad94-cecb308bdbae
# 350           350  d4e799b2-810f-4bf8-af59-94850c3c7655
# 396           396  98a94295-64be-4db5-9476-e62cbb370ad3
# 433           433  dc486f61-7215-4b1f-8ed5-2a7910b497a7
# 436           436  d499bfb6-07c1-4412-b201-e738f73df01e
# ...           ...                                   ...
# 35944       35944  e88f4128-be1a-48fe-8511-c47e0a218f2a
# 35956       35956  1c889bd6-354d-48bc-a46f-49d197f15b46
# 35958       35958  26b6009c-7978-404f-a636-d2bd1b373a33
# 35962       35962  66633f94-1a9d-45b4-b39f-27d2f526e071
# 35971       35971  591cc743-0a49-4e2a-a83d-f8b211ffb9c9
#
#                             userName  \
# 344                  Isaac Fernandes
# 350                   Wesley Pereira
# 396          andré marques gonçalves
# 433                   Guthy Oliveira
# 436                 Suzane Gonçalves
# ...                              ...
# ...

# %%
import seaborn as sns

sns.histplot(data = df, x= 'word_count')
# Out:
# <Axes: xlabel='word_count', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

def count_words(text_column):
  df['word_count'] = df[text_column].str.split().apply(len)

  min = df['word_count'].min()
  mean = df['word_count'].mean()
  max = df['word_count'].max()

  print('número minimo ', min )
  print('número médio ', mean)
  print('número maximo ', max)

  print('\nhistograma da frquencia de nueros de palavras')
  sns.histplot(data = df, x= 'word_count')
  plt.show()

# %%
count_words('content')
# Out:
# número minimo  1
# número médio  28.090712022678005
# número maximo  350
#
# histograma da frquencia de nueros de palavras

# %%
score_count = df['score'].value_counts()

# %% [markdown]
# Verificando a disribuição dos scores

# %%
sns.histplot(data = df, x= 'score', discrete = True)
# Out:
# <Axes: xlabel='score', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

plt.pie(score_count, labels = score_count.index, autopct='%1.1f%%')
plt.title('distribuição dos scores')
plt.axis('equal')
plt.show()

# %%
def class_distribuition(class_column):
  class_counts = df[class_column].value_counts()

  print('número de instancia por classes')
  print(class_counts)

  print('\nhistograma')
  sns.histplot(data = df, x = class_column, discrete = True)
  plt.title('Histograma')
  plt.show()

  print('\npizza')
  plt.pie(class_counts, labels = class_counts.index, autopct='%1.1f%%')
  plt.title('distribuição dos scores')
  plt.axis('equal')
  plt.show()

# %%
class_distribuition('score')
# Out:
# número de instancia por classes
# score
# 4    9000
# 5    9000
# 1    5994
# 2    5994
# 3    5994
# Name: count, dtype: int64
#
# histograma
# pizza

# %% [markdown]
# ## Palavras mais frequentes

# %%
from collections import Counter

all_text = ' '.join(df['content'])
words = all_text.split()
word_count = Counter(words)
most_comon_words = word_count.most_common(20)
most_comon_words_df = pd.DataFrame(most_comon_words, columns = ['palavra', 'frequencia'])
most_comon_words_df
# Out:
#    palavra  frequencia
# 0        o       34379
# 1       de       32419
# 2        e       30626
# 3      que       24527
# 4      não       22092
# 5        a       19925
# 6        é       12873
# 7      com       10660
# 8       do       10532
# 9       um        9547
# 10      no        9428
# 11    para        8960
# 12     app        8677
# 13   muito        8151
# 14      em        7730
# 15    mais        7411
# 16     tem        6891
# 17     mas        6549
# 18  pedido        6352
# 19      os        6216

# %%
def most_frequency_words(df, text_column, number_words = 10):
  all_text = ' '.join(df[text_column])
  words = all_text.split()
  word_count = Counter(words)

  most_comon_words = word_count.most_common(number_words)
  most_comon_words_df = pd.DataFrame(most_comon_words, columns = ['palavra', 'frequencia'])
  display(most_comon_words_df)

# %%
most_frequency_words(df, 'content', 50)
# Out:
#        palavra  frequencia
# 0            o       34379
# 1           de       32419
# 2            e       30626
# 3          que       24527
# 4          não       22092
# 5            a       19925
# 6            é       12873
# 7          com       10660
# 8           do       10532
# 9           um        9547
# 10          no        9428
# 11        para        8960
# 12         app        8677
# 13       muito        8151
# 14          em        7730
# 15        mais        7411
# 16         tem        6891
# 17         mas        6549
# 18      pedido        6352
# 19          os        6216
# 20          na        6054
# 21         uma        5760
# 22           O        5750
# 23         pra        5141
# 24         por        5099
# 25          da        4989
# 26  aplicativo        4936
# 27          as        4399
# 28          eu        4370
# 29          se        4221
# 30         meu        3783
# 31          só        3520
# 32         bom        3487
# ...

# %% [markdown]
# ## Palavraas mais frequentes por classe

# %%
for class_label in df['score'].unique():
  class_df = df[df['score'] == class_label]
  most_frequency_words(class_df, 'content', 20)
# Out:
#    palavra  frequencia
# 0        o        8542
# 1        e        7476
# 2       de        6939
# 3      não        6575
# 4      que        5650
# 5        a        4309
# 6      com        2598
# 7       um        2510
# 8       no        2379
# 9       do        2304
# 10  pedido        2125
# 11       é        2125
# 12    para        2006
# 13     app        1771
# 14      em        1660
# 15     uma        1483
# 16    mais        1481
# 17     tem        1372
# 18     pra        1316
# 19      na        1315
#    palavra  frequencia
# 0        o        7796
# 1       de        6708
# 2        e        6304
# 3      não        5618
# 4      que        5422
# 5        a        4260
# 6        é        2541
# 7      com        2266
# 8       do        2175
# 9       no        2090
# 10    para        2039
# 11      um        1995
# 12     app        1947
# 13      em        1686
# 14  pedido        1524
# 15     tem        1460
# 16      na        1406
# 17     mas        1402
# ...

# %%
def most_frequency_words_by_class(df, text_column, class_column, number_words = 10):
  for class_label in df[class_column].unique():
    class_df = df[df[class_column] == class_label]

# %%
most_frequency_words_by_class(df, 'content', 'score', 20)

# %%
pip install wordCloud

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud

all_text = ' '.join(df['content'])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def word_cloud(text_column):
  all_text = ' '.join(df[text_column])

  wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

  plt.figure(figsize=(10, 5))
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis('off')
  plt.show

# %%
word_cloud('content')

# %% [markdown]
# ## Compilando as funções

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud

def data_analysis(df, text_column, class_column):
  check_nulls()
  count_words(text_column)
  class_distribuition(class_column)
  most_frequency_words(df, text_column)
  most_frequency_words_by_class(df, text_column, class_column, 20)
  word_cloud(text_column)

# %%
data_analysis(df, 'content', 'score')
# Out:
# Unnamed: 0                  0
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     3361
# at                          0
# replyContent            27020
# repliedAt               27020
# appVersion               3361
# sortOrder                   0
# appId                       0
# word_count                  0
# dtype: int64
#
# número minimo  1
# número médio  28.090712022678005
# número maximo  350
#
# histograma da frquencia de nueros de palavras
# número de instancia por classes
# score
# 4    9000
# 5    9000
# 1    5994
# 2    5994
# 3    5994
# Name: count, dtype: int64
#
# histograma
# pizza
#   palavra  frequencia
# 0       o       34379
# 1      de       32419
# 2       e       30626
# 3     que       24527
# 4     não       22092
# 5       a       19925
# 6       é       12873
# 7     com       10660
# ...
